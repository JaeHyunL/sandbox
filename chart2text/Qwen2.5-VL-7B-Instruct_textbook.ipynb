# %%
# !pip install transformers qwen-vl-utils
# Out:
# Collecting transformers
#   Downloading transformers-5.13.0-py3-none-any.whl.metadata (32 kB)
# Collecting qwen-vl-utils
#   Downloading qwen_vl_utils-0.0.14-py3-none-any.whl.metadata (9.0 kB)
# Collecting huggingface-hub<2.0,>=1.5.0 (from transformers)
#   Downloading huggingface_hub-1.22.0-py3-none-any.whl.metadata (14 kB)
# Collecting numpy>=1.17 (from transformers)
#   Downloading numpy-2.2.6-cp310-cp310-macosx_14_0_arm64.whl.metadata (62 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/knocklab/workspace/dev_space/sandbox/.venv/lib/python3.10/site-packages (from transformers) (26.2)
# Collecting pyyaml>=5.1 (from transformers)
#   Downloading pyyaml-6.0.3-cp310-cp310-macosx_11_0_arm64.whl.metadata (2.4 kB)
# Collecting regex>=2025.10.22 (from transformers)
#   Downloading regex-2026.6.28-cp310-cp310-macosx_11_0_arm64.whl.metadata (40 kB)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers)
#   Downloading tokenizers-0.22.2-cp39-abi3-macosx_11_0_arm64.whl.metadata (7.3 kB)
# Collecting typer (from transformers)
#   Downloading typer-0.26.8-py3-none-any.whl.metadata (15 kB)
# Collecting safetensors>=0.8.0 (from transformers)
#   Downloading safetensors-0.8.0-cp310-abi3-macosx_11_0_arm64.whl.metadata (4.2 kB)
# Collecting tqdm>=4.60 (from transformers)
#   Downloading tqdm-4.68.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /Users/knocklab/workspace/dev_space/sandbox/.venv/lib/python3.10/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (8.4.2)
# Collecting filelock>=3.10.0 (from huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading filelock-3.29.5-py3-none-any.whl.metadata (2.0 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading fsspec-2026.6.0-py3-none-any.whl.metadata (10 kB)
# Collecting hf-xet<2.0.0,>=1.5.1 (from huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading hf_xet-1.5.1-cp37-abi3-macosx_11_0_arm64.whl.metadata (4.9 kB)
# Collecting httpx<1,>=0.23.0 (from huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/knocklab/workspace/dev_space/sandbox/.venv/lib/python3.10/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.16.0)
# Collecting anyio (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading anyio-4.14.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting certifi (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading certifi-2026.6.17-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting idna (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading idna-3.18-py3-none-any.whl.metadata (6.1 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers)
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting av (from qwen-vl-utils)
#   Downloading av-17.1.0-cp310-cp310-macosx_14_0_arm64.whl.metadata (4.6 kB)
# Collecting pillow (from qwen-vl-utils)
#   Downloading pillow-12.3.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (9.1 kB)
# Collecting requests (from qwen-vl-utils)
#   Downloading requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/knocklab/workspace/dev_space/sandbox/.venv/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.3.1)
# Collecting charset_normalizer<4,>=2 (from requests->qwen-vl-utils)
#   Downloading charset_normalizer-3.4.7-cp310-cp310-macosx_10_9_universal2.whl.metadata (40 kB)
# Collecting urllib3<3,>=1.26 (from requests->qwen-vl-utils)
#   Downloading urllib3-2.7.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting shellingham>=1.3.0 (from typer->transformers)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=13.8.0 (from typer->transformers)
#   Downloading rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting annotated-doc>=0.0.2 (from typer->transformers)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=13.8.0->typer->transformers)
#   Downloading markdown_it_py-4.2.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/knocklab/workspace/dev_space/sandbox/.venv/lib/python3.10/site-packages (from rich>=13.8.0->typer->transformers) (2.20.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading transformers-5.13.0-py3-none-any.whl (11.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 492.4 kB/s  0:00:23m0:00:0100:02
# Downloading huggingface_hub-1.22.0-py3-none-any.whl (765 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 765.1/765.1 kB 1.0 MB/s  0:00:00m eta 0:00:01
# Downloading hf_xet-1.5.1-cp37-abi3-macosx_11_0_arm64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 472.2 kB/s  0:00:07 eta 0:00:01
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading tokenizers-0.22.2-cp39-abi3-macosx_11_0_arm64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 379.8 kB/s  0:00:07 eta 0:00:01
# Downloading qwen_vl_utils-0.0.14-py3-none-any.whl (8.1 kB)
# Downloading filelock-3.29.5-py3-none-any.whl (45 kB)
# Downloading fsspec-2026.6.0-py3-none-any.whl (203 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading numpy-2.2.6-cp310-cp310-macosx_14_0_arm64.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 500.4 kB/s  0:00:10 eta 0:00:01
# Downloading pyyaml-6.0.3-cp310-cp310-macosx_11_0_arm64.whl (174 kB)
# Downloading regex-2026.6.28-cp310-cp310-macosx_11_0_arm64.whl (289 kB)
# Downloading safetensors-0.8.0-cp310-abi3-macosx_11_0_arm64.whl (484 kB)
# Downloading tqdm-4.68.3-py3-none-any.whl (78 kB)
# Downloading anyio-4.14.1-py3-none-any.whl (124 kB)
# Downloading idna-3.18-py3-none-any.whl (65 kB)
# Downloading av-17.1.0-cp310-cp310-macosx_14_0_arm64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 329.6 kB/s  0:01:10m0:00:0100:03
# Downloading certifi-2026.6.17-py3-none-any.whl (133 kB)
# Downloading pillow-12.3.0-cp310-cp310-macosx_11_0_arm64.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 536.2 kB/s  0:00:08 eta 0:00:01
# Downloading requests-2.34.2-py3-none-any.whl (73 kB)
# Downloading charset_normalizer-3.4.7-cp310-cp310-macosx_10_9_universal2.whl (315 kB)
# Downloading urllib3-2.7.0-py3-none-any.whl (131 kB)
# Downloading typer-0.26.8-py3-none-any.whl (122 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading rich-15.0.0-py3-none-any.whl (310 kB)
# Downloading markdown_it_py-4.2.0-py3-none-any.whl (91 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Installing collected packages: urllib3, tqdm, shellingham, safetensors, regex, pyyaml, pillow, numpy, mdurl, idna, hf-xet, h11, fsspec, filelock, charset_normalizer, certifi, av, annotated-doc, requests, markdown-it-py, httpcore, anyio, rich, qwen-vl-utils, httpx, typer, huggingface-hub, tokenizers, transformers
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29/29 [transformers] [transformers]ub]
# Successfully installed annotated-doc-0.0.4 anyio-4.14.1 av-17.1.0 certifi-2026.6.17 charset_normalizer-3.4.7 filelock-3.29.5 fsspec-2026.6.0 h11-0.16.0 hf-xet-1.5.1 httpcore-1.0.9 httpx-0.28.1 huggingface-hub-1.22.0 idna-3.18 markdown-it-py-4.2.0 mdurl-0.1.2 numpy-2.2.6 pillow-12.3.0 pyyaml-6.0.3 qwen-vl-utils-0.0.14 regex-2026.6.28 requests-2.34.2 rich-15.0.0 safetensors-0.8.0 shellingham-1.5.4 tokenizers-0.22.2 tqdm-4.68.3 transformers-5.13.0 typer-0.26.8 urllib3-2.7.0

# %%
from transformers import Qwen2_5_VLForConditionalGeneration, AutoTokenizer, AutoProcessor
from qwen_vl_utils import process_vision_info

# default: Load the model on the available device(s)
model = Qwen2_5_VLForConditionalGeneration.from_pretrained(
    "Qwen/Qwen2.5-VL-7B-Instruct", torch_dtype="auto", device_map="auto"
)

# We recommend enabling flash_attention_2 for better acceleration and memory saving, especially in multi-image and video scenarios.
# model = Qwen2_5_VLForConditionalGeneration.from_pretrained(
#     "Qwen/Qwen2.5-VL-7B-Instruct",
#     torch_dtype=torch.bfloat16,
#     attn_implementation="flash_attention_2",
#     device_map="auto",
# )

# default processer
processor = AutoProcessor.from_pretrained("Qwen/Qwen2.5-VL-7B-Instruct")

# The default range for the number of visual tokens per image in the model is 4-16384.
# You can set min_pixels and max_pixels according to your needs, such as a token range of 256-1280, to balance performance and cost.
# min_pixels = 256*28*28
# max_pixels = 1280*28*28
# processor = AutoProcessor.from_pretrained("Qwen/Qwen2.5-VL-7B-Instruct", min_pixels=min_pixels, max_pixels=max_pixels)

messages = [
    {
        "role": "user",
        "content": [
            {
                "type": "image",
                "image": "https://qianwen-res.oss-cn-beijing.aliyuncs.com/Qwen-VL/assets/demo.jpeg",
            },
            {"type": "text", "text": "Describe this image."},
        ],
    }
]

# Preparation for inference
text = processor.apply_chat_template(
    messages, tokenize=False, add_generation_prompt=True
)
image_inputs, video_inputs = process_vision_info(messages)
inputs = processor(
    text=[text],
    images=image_inputs,
    videos=video_inputs,
    padding=True,
    return_tensors="pt",
)
inputs = inputs.to("cuda")

# Inference: Generation of the output
generated_ids = model.generate(**inputs, max_new_tokens=128)
generated_ids_trimmed = [
    out_ids[len(in_ids) :] for in_ids, out_ids in zip(inputs.input_ids, generated_ids)
]
output_text = processor.batch_decode(
    generated_ids_trimmed, skip_special_tokens=True, clean_up_tokenization_spaces=False
)
print(output_text)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from transformers import Qwen2_5_VLForConditionalGeneration, AutoTokenizer, AutoProcessor
#       2 from qwen_vl_utils import process_vision_info
#       4 # default: Load the model on the available device(s)
#
# ModuleNotFoundError: No module named 'transformers'
